# %%
from sklearn.datasets import make_classification
import numpy as np 
X,Y = make_classification(n_samples = 100, n_features = 2, n_informative = 1 , n_redundant = 0,n_classes = 2, n_clusters_per_class = 1, random_state = 42, hypercube = False, class_sep= 3)
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c = Y)

# %%
Y = [-1 if x == 0 else x for x in Y]

# %%
class perceptron_gradient:
    def __init__(self,X,Y,epochs=10,lr= 0.1):
        self.X = X
        self.Y = Y
        self.epochs = epochs
        self.lr = lr

    def fit(self):
        w1=w2=b =1
       
        for i in range(self.epochs):
            for j in range(self.X.shape[0]):
                z = w1*X[j][0] + w2*X[j][1] +b
                if z*Y[j] <0:
                    w1 = w1+ self.lr*X[j][0]*Y[j]
                    w2 = w2+ self.lr*X[j][1]*Y[j]
                    b = b+ self.lr*Y[j]
        return b,w1,w2

# %%
percp1 = perceptron_gradient(X,Y)
b,W0,W1 = percp1.fit()
b = -b/W1
m = -W0/W1

# %%
print(b , m)
# Out:
# 0.43698530400900515 -0.0740228145667022

# %%
plt.scatter(X[:,0],X[:,1],c = Y)
X_input = np.linspace(-2.5,3,1000)
y_input = m*(X_input) + b
plt.plot(X_input,y_input)
